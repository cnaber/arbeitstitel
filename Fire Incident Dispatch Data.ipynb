# %%
import os
import pandas as pd

# %%
df = pd.read_csv("../../data/response/Fire_Incident_Dispatch_Data.csv")
is_valid_rspns_time = df['VALID_INCIDENT_RSPNS_TIME_INDC'] == 'Y'
valid_rspns_times = df[is_valid_rspns_time]

# %%
valid_rspns_times.shape
# Out:
# (2757412, 29)

# %%
sorted = valid_rspns_times.sort_values(by=['INCIDENT_TRAVEL_TM_SECONDS_QY'], ascending=False)
print(sorted['INCIDENT_TRAVEL_TM_SECONDS_QY'].quantile(.05))
print(sorted['INCIDENT_TRAVEL_TM_SECONDS_QY'].quantile(.95))
# Out:
# 130.0
# 480.0

# %%
sorted
# Out:
#          STARFIRE_INCIDENT_ID       INCIDENT_DATETIME  \
# 868409           1.721326e+15  08/01/2017 10:57:22 PM
# 238039           1.822724e+15  08/15/2018 02:08:22 PM
# 223451           1.823699e+15  08/24/2018 01:16:35 AM
# 124919           1.829273e+15  10/19/2018 10:12:33 AM
# 3322044          1.304116e+15  02/10/2013 05:27:54 PM
# 2668421          1.416174e+15  06/10/2014 12:06:34 PM
# 164824           1.826933e+15  09/26/2018 11:23:55 AM
# 2283784          1.505934e+15  02/28/2015 09:00:49 AM
# 765660           1.727632e+15  10/03/2017 08:50:51 PM
# 1580357          1.613880e+15  05/17/2016 07:15:52 PM
# 2903229          1.335906e+15  12/25/2013 10:40:02 PM
# 223125           1.823646e+15  08/24/2018 09:00:22 AM
# 757285           1.728180e+15  10/08/2017 11:03:59 PM
# 2189091          1.512094e+15  04/30/2015 02:43:43 PM
# 900094           1.719438e+15  07/13/2017 11:05:33 PM
# 1964201          1.525635e+15  09/13/2015 08:13:12 PM
# ...

# %%
# Out:
# 130.0
# 480.0

# %%
# Out:
# (2757412, 29)
