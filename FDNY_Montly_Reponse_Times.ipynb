# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../../data/response/FDNY_Monthly_Response_Times.csv")
df = df.sort_values(by=['AVERAGERESPONSETIME', 'INCIDENTCOUNT'], ascending=False)
df.head(10)
# Out:
#      YEARMONTH  INCIDENTCLASSIFICATION INCIDENTBOROUGH  INCIDENTCOUNT  \
# 2373   2014/03     Medical False Alarm   Staten Island              6
# 3129   2015/09     Medical False Alarm   Staten Island              3
# 1667   2012/10  NonMedical Emergencies          Queens           5528
# 1709   2012/11  NonMedical Emergencies          Queens           6905
# 1671   2012/10     NonStructural Fires   Staten Island             62
# 1665   2012/10  NonMedical Emergencies   Staten Island           1713
# 363    2010/03  NonMedical Emergencies   Staten Island           2253
# 743    2010/12  NonMedical Emergencies          Queens           4170
# 2295   2014/01  NonMedical Emergencies   Staten Island           1384
# 2843   2015/02  NonMedical Emergencies          Queens           4722
#
#      AVERAGERESPONSETIME
# 2373               07:06
# 3129               06:38
# 1667               06:34
# 1709               06:24
# 1671               06:14
# 1665               06:12
# ...

# %%
staten_island_filter = df['INCIDENTBOROUGH']=='Staten Island'
staten_island_incidents = df[staten_island_filter]
staten_island_incidents = staten_island_incidents.sort_values(by='YEARMONTH')
staten_island_incidents
# Out:
#      YEARMONTH        INCIDENTCLASSIFICATION INCIDENTBOROUGH  INCIDENTCOUNT  \
# 27     2009/07        NonMedical Emergencies   Staten Island            877
# 15     2009/07           Medical Emergencies   Staten Island            933
# 21     2009/07           Medical False Alarm   Staten Island             10
# 39     2009/07              Structural Fires   Staten Island             90
# 9      2009/07                   False Alarm   Staten Island            192
# 33     2009/07           NonStructural Fires   Staten Island            103
# 3      2009/07  All Fire/Emergency Incidents   Staten Island           2205
# 81     2009/08              Structural Fires   Staten Island             80
# 45     2009/08  All Fire/Emergency Incidents   Staten Island           2009
# 69     2009/08        NonMedical Emergencies   Staten Island            834
# 51     2009/08                   False Alarm   Staten Island            198
# ...

# %%
dirpath = os.getcwd()
print("current directory is : " + dirpath)
# Out:
# current directory is : C:\Users\cnaber\Arbeit\hackaton\MHP AI Challenge\git\arbeitstitel
